# %%
import torch
torch.cuda.is_available()
# Out:
# Cloning into 'ML_4_MAXCUT'...
# remote: Enumerating objects: 436, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 436 (delta 19), reused 32 (delta 14), pack-reused 392 (from 1)
# Receiving objects: 100% (436/436), 341.42 MiB | 29.66 MiB/s, done.
# Resolving deltas: 100% (192/192), done.

# %%
# !git clone https://github.com/victor99pekk/ML_4_MAXCUT.git
# %cd ML_4_MAXCUT
# Out:
# True

# %%
# !make gen_data edge_mode=real nbr_nodes=5 datatype=test
# !make gen_data edge_mode=real nbr_nodes=5 datatype=validation
# Out:
# object address  : 0x13f5eabe0ca0
# object refcount : 2
# object type     : 0x9d7580
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C

# %%
# !make gen_data edge_mode=real nbr_nodes=5 datatype=train

# %%
# !python neural_network/train_network.py

# %%
# !unzip data/test.zip -d data/test/
# !unzip data/train.zip -d data/train/

# %%
# !python neural_network/evaluate_network.py
