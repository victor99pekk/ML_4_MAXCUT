# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# !git clone https://github.com/victor99pekk/ML_4_MAXCUT.git
# %cd ML_4_MAXCUT
# Out:
# True

# %%
n = 30
graph_type = "projection_planting" #projection_planting, bqp_planting

# %%
# !make gen_data graph_type={graph_type} nbr_nodes={n} data_type=validation
# !make gen_data graph_type={graph_type} nbr_nodes={n} data_type=test
# !make gen_data graph_type={graph_type} nbr_nodes={n} data_type=train
# Out:
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/data/gen_maxcut_data.py --nbr_nodes 30 --graph_type projection_planting --data_type validation
# mean= 0.45, std=0.55
# Density: 0.97
# Saved 1000 graphs to 'data/validation/validation_n=30.csv' (row length = 931)
# Done in 0.4 seconds.
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/data/gen_maxcut_data.py --nbr_nodes 30 --graph_type projection_planting --data_type test
# mean= 0.45, std=0.55
# Density: 0.97
# Saved 1000 graphs to 'data/test/test_n=30.csv' (row length = 931)
# Done in 0.4 seconds.
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/data/gen_maxcut_data.py --nbr_nodes 30 --graph_type projection_planting --data_type train
# mean= 0.45, std=0.55
# Density: 0.97
# Saved 100000 graphs to 'data/train/train_n=30.csv' (row length = 931)
# Done in 49.2 seconds.

# %%
model = "transformer"  # "lstm", "transformer", "gat"
graph_encoding = True  # True, False
# !make train model={model} nbr_nodes={n} graph_encoding={graph_encoding}
# Out:
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/neural_network/train_network.py --nbr_nodes 30 --model transformer --graph_encoding True
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/cuda/amp/grad_scaler.py:126: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#
#
# Processed 500 samples; remaining in epoch: 99520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 1000 samples; remaining in epoch: 99020
#
# cut / optimal: 393.1999997496605/5346.56  =  0.07
#
#
# Processed 1500 samples; remaining in epoch: 98520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 2000 samples; remaining in epoch: 98020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 2500 samples; remaining in epoch: 97520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 3000 samples; remaining in epoch: 97020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 3500 samples; remaining in epoch: 96520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 4000 samples; remaining in epoch: 96020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 4500 samples; remaining in epoch: 95520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 5000 samples; remaining in epoch: 95020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 5500 samples; remaining in epoch: 94520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 6000 samples; remaining in epoch: 94020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 6500 samples; remaining in epoch: 93520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 7000 samples; remaining in epoch: 93020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 7500 samples; remaining in epoch: 92520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 8000 samples; remaining in epoch: 92020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 8500 samples; remaining in epoch: 91520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 9000 samples; remaining in epoch: 91020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 9500 samples; remaining in epoch: 90520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 10000 samples; remaining in epoch: 90020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 10500 samples; remaining in epoch: 89520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 11000 samples; remaining in epoch: 89020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 11500 samples; remaining in epoch: 88520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 12000 samples; remaining in epoch: 88020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 12500 samples; remaining in epoch: 87520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 13000 samples; remaining in epoch: 87020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 13500 samples; remaining in epoch: 86520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 14000 samples; remaining in epoch: 86020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 14500 samples; remaining in epoch: 85520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 15000 samples; remaining in epoch: 85020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 15500 samples; remaining in epoch: 84520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 16000 samples; remaining in epoch: 84020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 16500 samples; remaining in epoch: 83520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 17000 samples; remaining in epoch: 83020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 17500 samples; remaining in epoch: 82520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 18000 samples; remaining in epoch: 82020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 18500 samples; remaining in epoch: 81520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 19000 samples; remaining in epoch: 81020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 19500 samples; remaining in epoch: 80520
#
# cut / optimal: 3358.649992980063/5346.56  =  0.63
#
#
# Processed 20000 samples; remaining in epoch: 80020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 20500 samples; remaining in epoch: 79520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 21000 samples; remaining in epoch: 79020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 21500 samples; remaining in epoch: 78520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 22000 samples; remaining in epoch: 78020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 22500 samples; remaining in epoch: 77520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 23000 samples; remaining in epoch: 77020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 23500 samples; remaining in epoch: 76520
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 24000 samples; remaining in epoch: 76020
#
# cut / optimal: 0/5346.56  =  0.00
#
#
# Processed 24500 samples; remaining in epoch: 75520
#
# cut / optimal: 0/5346.56  =  0.00
# ^C
# Traceback (most recent call last):
#   File "/Users/victorpekkari/Desktop/UCSD/maxcut/neural_network/train_network.py", line 393, in <module>
#     main()
#   File "/Users/victorpekkari/Desktop/UCSD/maxcut/neural_network/train_network.py", line 369, in main
#     torch.save(model.state_dict(), f"{folder_path}/weights.pth")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/serialization.py", line 629, in save
#     _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/serialization.py", line 863, in _save
#     zip_file.write_record(name, storage.data_ptr(), num_bytes)
# KeyboardInterrupt

# %%
# !make evaluate model_name={model_name} n={n} compile_model={compile_model}
