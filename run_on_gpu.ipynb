# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# !git clone https://github.com/victor99pekk/ML_4_MAXCUT.git
# %cd ML_4_MAXCUT
# Out:
# True

# %%
n = 5
graph_type = "bqp_planting"

# %%
# !make gen_data graph_type={graph_type} nbr_nodes={n} data_type=validation
# !make gen_data graph_type={graph_type} nbr_nodes={n} data_type=test
# !make gen_data graph_type={graph_type} nbr_nodes={n} data_type=train
# Out:
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/data/gen_maxcut_data.py --nbr_nodes 5 --graph_type bqp_planting --data_type validation
# mean= 0.15, std=7.00
# Density: 0.80
# Saved 1000 graphs to 'data/validation/validation_n=5.csv' (row length = 31)
# Done in 0.0 seconds.
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/data/gen_maxcut_data.py --nbr_nodes 5 --graph_type bqp_planting --data_type test
# mean= -0.14, std=6.83
# Density: 0.80
# Saved 1000 graphs to 'data/test/test_n=5.csv' (row length = 31)
# Done in 0.0 seconds.
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/data/gen_maxcut_data.py --nbr_nodes 5 --graph_type bqp_planting --data_type train
# mean= -0.05, std=6.91
# Density: 0.80
# Saved 10000 graphs to 'data/train/train_n=5.csv' (row length = 31)
# Done in 0.5 seconds.

# %%
# !unzip data/test.zip -d data/test/
# !unzip data/train.zip -d data/train/
# !unzip data/validation.zip -d data/validation/

# %%
model = "lstm"  # "lstm", "transformer", "gat"
# !make train model={model} nbr_nodes={n}
# Out:
# python3 /Users/victorpekkari/Desktop/UCSD/maxcut/neural_network/train_network.py --nbr_nodes 5 --model lstm
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/cuda/amp/grad_scaler.py:126: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#
#
# Processed 60 samples; remaining in epoch: 9960
#
# cut / optimal: -70.0/143.0  =  0.00
#
#
# Processed 120 samples; remaining in epoch: 9900
#
# cut / optimal: -178.0/143.0  =  0.00
#
#
# Processed 180 samples; remaining in epoch: 9840
#
# cut / optimal: -184.0/143.0  =  0.00
#
#
# Processed 240 samples; remaining in epoch: 9780
#
# cut / optimal: -229.0/143.0  =  0.00
#
#
# Processed 300 samples; remaining in epoch: 9720
#
# cut / optimal: -93.0/143.0  =  0.00
#
#
# Processed 360 samples; remaining in epoch: 9660
#
# cut / optimal: -149.0/143.0  =  0.00
#
#
# Processed 420 samples; remaining in epoch: 9600
#
# cut / optimal: -237.0/143.0  =  0.00
#
#
# Processed 480 samples; remaining in epoch: 9540
#
# cut / optimal: -121.0/143.0  =  0.00
#
#
# Processed 540 samples; remaining in epoch: 9480
#
# cut / optimal: -145.0/143.0  =  0.00
#
#
# Processed 600 samples; remaining in epoch: 9420
#
# cut / optimal: -232.0/143.0  =  0.00
#
#
# Processed 660 samples; remaining in epoch: 9360
#
# cut / optimal: -186.0/143.0  =  0.00
#
#
# Processed 720 samples; remaining in epoch: 9300
#
# cut / optimal: -175.0/143.0  =  0.00
#
#
# Processed 780 samples; remaining in epoch: 9240
#
# cut / optimal: -190.0/143.0  =  0.00
#
#
# Processed 840 samples; remaining in epoch: 9180
#
# cut / optimal: -156.0/143.0  =  0.00
#
#
# Processed 900 samples; remaining in epoch: 9120
#
# cut / optimal: -110.0/143.0  =  0.00
#
#
# Processed 960 samples; remaining in epoch: 9060
#
# cut / optimal: -146.0/143.0  =  0.00
#
#
# Processed 1020 samples; remaining in epoch: 9000
#
# cut / optimal: -21.0/143.0  =  0.00
#
#
# Processed 1080 samples; remaining in epoch: 8940
#
# cut / optimal: -190.0/143.0  =  0.00
#
#
# Processed 1140 samples; remaining in epoch: 8880
#
# cut / optimal: -189.0/143.0  =  0.00
#
#
# Processed 1200 samples; remaining in epoch: 8820
#
# cut / optimal: -84.0/143.0  =  0.00
#
#
# Processed 1260 samples; remaining in epoch: 8760
#
# cut / optimal: -49.0/143.0  =  0.00
#
#
# Processed 1320 samples; remaining in epoch: 8700
#
# cut / optimal: -44.0/143.0  =  0.00
#
#
# Processed 1380 samples; remaining in epoch: 8640
#
# cut / optimal: -33.0/143.0  =  0.00
#
#
# Processed 1440 samples; remaining in epoch: 8580
#
# cut / optimal: 5.0/143.0  =  0.03
#
#
# Processed 1500 samples; remaining in epoch: 8520
#
# cut / optimal: -145.0/143.0  =  0.00
#
#
# Processed 1560 samples; remaining in epoch: 8460
#
# cut / optimal: -50.0/143.0  =  0.00
#
#
# Processed 1620 samples; remaining in epoch: 8400
#
# cut / optimal: -62.0/143.0  =  0.00
#
#
# Processed 1680 samples; remaining in epoch: 8340
#
# cut / optimal: -178.0/143.0  =  0.00
#
#
# Processed 1740 samples; remaining in epoch: 8280
#
# cut / optimal: -139.0/143.0  =  0.00
#
#
# Processed 1800 samples; remaining in epoch: 8220
#
# cut / optimal: -38.0/143.0  =  0.00
#
#
# Processed 1860 samples; remaining in epoch: 8160
#
# cut / optimal: -113.0/143.0  =  0.00
#
#
# Processed 1920 samples; remaining in epoch: 8100
#
# cut / optimal: -96.0/143.0  =  0.00
#
#
# Processed 1980 samples; remaining in epoch: 8040
#
# cut / optimal: -98.0/143.0  =  0.00
#
#
# Processed 2040 samples; remaining in epoch: 7980
#
# cut / optimal: -76.0/143.0  =  0.00
#
#
# Processed 2100 samples; remaining in epoch: 7920
#
# cut / optimal: -76.0/143.0  =  0.00
#
#
# Processed 2160 samples; remaining in epoch: 7860
#
# cut / optimal: -137.0/143.0  =  0.00
#
#
# Processed 2220 samples; remaining in epoch: 7800
#
# cut / optimal: -31.0/143.0  =  0.00
#
#
# Processed 2280 samples; remaining in epoch: 7740
#
# cut / optimal: -17.0/143.0  =  0.00
#
#
# Processed 2340 samples; remaining in epoch: 7680
#
# cut / optimal: -147.0/143.0  =  0.00
#
#
# Processed 2400 samples; remaining in epoch: 7620
#
# cut / optimal: -36.0/143.0  =  0.00
#
#
# Processed 2460 samples; remaining in epoch: 7560
#
# cut / optimal: -44.0/143.0  =  0.00
#
#
# Processed 2520 samples; remaining in epoch: 7500
#
# cut / optimal: -108.0/143.0  =  0.00
# ^C

# %%
# !make evaluate model_name={model_name} n={n} compile_model={compile_model}
